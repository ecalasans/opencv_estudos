# %%
import matplotlib.pyplot as plt
import cv2
import jupytercv


img = cv2.imread('rosas.jpeg')
jupytercv.imshow_grayscale(img)

b, g, r = cv2.split(img)

print(g)
# Out:
# [[235 251 194 ... 234 234 234]
#  [216 224 200 ... 234 234 234]
#  [216 227 217 ... 234 234 234]
#  ...
#  [ 86 100  60 ... 234 234 234]
#  [ 76  97  92 ... 236 236 236]
#  [ 76  97  92 ... 236 236 236]]
